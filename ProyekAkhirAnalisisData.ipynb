# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Dwi Laras Setyadita
# - **Email:** larassetyadita@gmail.com
# - **ID Dicoding:** larassetyadita

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimanakah kualitas udara di setiap kota berdasarkan polutan PM2.5?
#
# - Bagaimanakah tren suhu taunan terjadi di seluruh kota setiap bulannya?

# %% [markdown]
# ## Import Semua Packges/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# load data stasiun Aotizongxin
aotizongxin_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
aotizongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
# load data stasiun Changping
changping_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv")
changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
# load data stasiun Dingling
dingling_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv")
dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
# load data stasiun Dongsi
dongsi_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv")
dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
# load data stasiun Guanyuan
guanyuan_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Guanyuan_20130301-20170228.csv")
guanyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
# load data stasiun Gucheng
gucheng_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv")
gucheng_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
# load data stasiun Huairou
huairou_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Huairou_20130301-20170228.csv")
huairou_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
# load data stasiun Nongzhanguan
nongzhanguan_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Nongzhanguan_20130301-20170228.csv")
nongzhanguan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
# load data stasiun Shunyi
shunyi_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv")
shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
# load data stasiun Tiantian
tiantan_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Tiantan_20130301-20170228.csv")
tiantan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
# load data stasiun Wanliu
wanliu_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Wanliu_20130301-20170228.csv")
wanliu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
# load data stasiun aotizongxin
wanshouxigong_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Wanshouxigong_20130301-20170228.csv")
wanshouxigong_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai data stasiun Aotizongxin

# %%
# menilai data stasiun Aotizongxin
aotizongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
aotizongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", aotizongxin_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Changping

# %%
# menilai data stasiun Aotizongxin
changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", changping_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Dingling

# %%
# menilai data stasiun Dingling
dingling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", dingling_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Dongsi

# %%
# menilai data stasiun
dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", dongsi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Guanyuan

# %%
# menilai data stasiun
guanyuan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", guanyuan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Gucheng

# %%
# menilai data stasiun
gucheng_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
gucheng_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", gucheng_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Huairou

# %%
# menilai data stasiun
huairou_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
huairou_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", huairou_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Nongzhanguan

# %%
# menilai data stasiun
nongzhanguan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
nongzhanguan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", nongzhanguan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Shunyi

# %%
# menilai data stasiun
shunyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
shunyi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", shunyi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Tiantan

# %%
# menilai data stasiun
tiantan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
tiantan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", tiantan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Wanliu

# %%
# menilai data stasiun
wanliu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
wanliu_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", wanliu_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai data stasiun Wanshouxigong

# %%
# menilai data stasiun Aotizongxin
wanshouxigong_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# mencari informasi missing value
wanshouxigong_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %%
# mencari data duplikat
print("Jumlah duplikasi: ", wanshouxigong_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Membersihkan data Aotizongxin

# %%
# menghapus kolom yang tidak digunakan
aotizongxin_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# menangani missing value pada kolom PM2.5
aotizongxin_df[aotizongxin_df["PM2.5"].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP       station
# 1509    1510  2013      5    2    21    NaN  18.5  Aotizhongxin
# 1837    1838  2013      5   16    13    NaN  26.1  Aotizhongxin
# 2368    2369  2013      6    7    16    NaN  20.7  Aotizhongxin
# 2785    2786  2013      6   25     1    NaN  20.8  Aotizhongxin
# 2808    2809  2013      6   26     0    NaN  21.7  Aotizhongxin
# ...      ...   ...    ...  ...   ...    ...   ...           ...
# 34880  34881  2017      2   21     8    NaN  -0.3  Aotizhongxin
# 34883  34884  2017      2   21    11    NaN   1.3  Aotizhongxin
# 34885  34886  2017      2   21    13    NaN  -2.1  Aotizhongxin
# 35028  35029  2017      2   27    12    NaN  12.1  Aotizhongxin
# 35029  35030  2017      2   27    13    NaN  14.0  Aotizhongxin
#
# [925 rows x 8 columns]

# %%
aotizongxin_df["PM2.5"].fillna(aotizongxin_df["PM2.5"].median(), inplace=True)

# %%
# membersihkan data outlier
aotizongxin_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
aotizongxin_df['PM2.5'][aotizongxin_df['PM2.5'] > 600].hist(bins=15)
# Out:
# <Axes: >

# %%
# mengganti outlier dengan median
aotizongxin_df['PM2.5'].replace(aotizongxin_df['PM2.5'].max(), aotizongxin_df['PM2.5'].median(), inplace=True)

# %%
aotizongxin_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
# menangani missing value pada kolom TEMP
aotizongxin_df[aotizongxin_df["TEMP"].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP       station
# 16748  16749  2015      1   27    20   26.0   NaN  Aotizhongxin
# 17263  17264  2015      2   18     7   13.0   NaN  Aotizhongxin
# 31047  31048  2016      9   14    15   75.0   NaN  Aotizhongxin
# 31315  31316  2016      9   25    19  168.0   NaN  Aotizhongxin
# 31316  31317  2016      9   25    20  182.0   NaN  Aotizhongxin
# 31317  31318  2016      9   25    21  137.0   NaN  Aotizhongxin
# 31318  31319  2016      9   25    22  107.0   NaN  Aotizhongxin
# 31319  31320  2016      9   25    23   95.0   NaN  Aotizhongxin
# 31320  31321  2016      9   26     0   89.0   NaN  Aotizhongxin
# 33872  33873  2017      1   10     8    8.0   NaN  Aotizhongxin
# 33882  33883  2017      1   10    18    8.0   NaN  Aotizhongxin
# 34083  34084  2017      1   19     3   96.0   NaN  Aotizhongxin
# 34084  34085  2017      1   19     4  112.0   NaN  Aotizhongxin
# 34085  34086  2017      1   19     5  126.0   NaN  Aotizhongxin
# ...

# %%
# menangani missing value dengan nilai median
aotizongxin_df["TEMP"].fillna(aotizongxin_df["TEMP"].median(), inplace=True)

# %%
# melihat outlier dalam data temperatur
aotizongxin_df['TEMP'].hist(bins=15) # tidak ditemukan outlier
# Out:
# <Axes: >

# %% [markdown]
# ### Membersihkan data stasiun Changping

# %%
# menghapus kolom yang tidak digunakan
changping_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# mengangani missing value pada atribut PM2.5
changping_df[changping_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP    station
# 1308    1309  2013      4   24    12    NaN  22.6  Changping
# 1309    1310  2013      4   24    13    NaN  23.4  Changping
# 1814    1815  2013      5   15    14    NaN  27.7  Changping
# 1815    1816  2013      5   15    15    NaN  27.9  Changping
# 2417    2418  2013      6    9    17    NaN  17.8  Changping
# ...      ...   ...    ...  ...   ...    ...   ...        ...
# 34879  34880  2017      2   21     7    NaN  -1.7  Changping
# 34880  34881  2017      2   21     8    NaN  -1.8  Changping
# 34883  34884  2017      2   21    11    NaN  -0.5  Changping
# 34885  34886  2017      2   21    13    NaN  -1.0  Changping
# 34887  34888  2017      2   21    15    NaN  -2.1  Changping
#
# [774 rows x 8 columns]

# %%
# menangani missing value dengan median
changping_df['PM2.5'].fillna(changping_df['PM2.5'].median(), inplace=True)

# %%
changping_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
changping_df[changping_df['PM2.5'] >  500]
# Out:
#           No  year  month  day  hour  PM2.5    TEMP    station
# 8698    8699  2014      2   26    10  581.0   6.100  Changping
# 8699    8700  2014      2   26    11  524.0   6.900  Changping
# 8700    8701  2014      2   26    12  524.0   7.800  Changping
# 9669    9670  2014      4    7    21  510.0  16.500  Changping
# 11746  11747  2014      7    3    10  540.0  26.500  Changping
# 25778  25779  2016      2    8     2  882.0  -2.400  Changping
# 33369  33370  2016     12   20     9  507.0  -3.000  Changping
# 33371  33372  2016     12   20    11  552.0   1.200  Changping
# 33372  33373  2016     12   20    12  557.0   1.600  Changping
# 33395  33396  2016     12   21    11  517.0   1.100  Changping
# 33396  33397  2016     12   21    12  576.0   1.900  Changping
# 33397  33398  2016     12   21    13  596.0   3.300  Changping
# 33659  33660  2017      1    1    11  560.0  -3.700  Changping
# 33660  33661  2017      1    1    12  662.0  -1.700  Changping
# ...

# %%
# mengganti kedua outlier dengan median
changping_df['PM2.5'].replace(changping_df['PM2.5'].max(), changping_df['PM2.5'].median(), inplace=True)
changping_df['PM2.5'].replace(changping_df['PM2.5'].max(), changping_df['PM2.5'].median(), inplace=True)

# %%
changping_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
# menangani missing value pada atribut TEMP
changping_df[changping_df['TEMP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP    station
# 16748  16749  2015      1   27    20   35.0   NaN  Changping
# 16813  16814  2015      1   30    13   14.0   NaN  Changping
# 16829  16830  2015      1   31     5   10.0   NaN  Changping
# 16873  16874  2015      2    2     1   78.0   NaN  Changping
# 16883  16884  2015      2    2    11  139.0   NaN  Changping
# 16930  16931  2015      2    4    10   21.0   NaN  Changping
# 16933  16934  2015      2    4    13   15.0   NaN  Changping
# 17007  17008  2015      2    7    15    8.0   NaN  Changping
# 17030  17031  2015      2    8    14    8.0   NaN  Changping
# 17052  17053  2015      2    9    12   84.0   NaN  Changping
# 17053  17054  2015      2    9    13  110.0   NaN  Changping
# 17078  17079  2015      2   10    14   35.0   NaN  Changping
# 17090  17091  2015      2   11     2   19.0   NaN  Changping
# 17112  17113  2015      2   12     0   15.0   NaN  Changping
# ...

# %%
# mengisi kolom yang kosong dengan nilai median
changping_df['TEMP'].fillna(changping_df['TEMP'].median(), inplace=True)

# %%
# melihat outlier
changping_df['TEMP'].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# ### Membersihkan data stasiun Dingling

# %%
# menghapus kolom yang tidak digunakan
dingling_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
dingling_df[dingling_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP   station
# 752      753  2013      4    1     8    NaN  11.0  Dingling
# 753      754  2013      4    1     9    NaN  10.6  Dingling
# 754      755  2013      4    1    10    NaN  13.2  Dingling
# 755      756  2013      4    1    11    NaN  13.8  Dingling
# 756      757  2013      4    1    12    NaN  15.3  Dingling
# ...      ...   ...    ...  ...   ...    ...   ...       ...
# 34863  34864  2017      2   20    15    NaN   4.2  Dingling
# 34864  34865  2017      2   20    16    NaN   4.4  Dingling
# 34866  34867  2017      2   20    18    NaN   3.3  Dingling
# 34883  34884  2017      2   21    11    NaN  -0.5  Dingling
# 34885  34886  2017      2   21    13    NaN  -1.0  Dingling
#
# [779 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
dingling_df['PM2.5'].fillna(dingling_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
dingling_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
dingling_df['PM2.5'][dingling_df['PM2.5'] > 600].hist(bins=15)
# Out:
# <Axes: >

# %%
dingling_df['PM2.5'].replace(dingling_df['PM2.5'].max(), dingling_df['PM2.5'].median(), inplace=True)

# %%
dingling_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
# melihat missing value pada atribut TEMP
dingling_df[dingling_df['TEMP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP   station
# 16748  16749  2015      1   27    20   39.0   NaN  Dingling
# 16813  16814  2015      1   30    13   15.0   NaN  Dingling
# 16829  16830  2015      1   31     5    5.0   NaN  Dingling
# 16873  16874  2015      2    2     1   60.0   NaN  Dingling
# 16883  16884  2015      2    2    11  138.0   NaN  Dingling
# 16930  16931  2015      2    4    10    8.0   NaN  Dingling
# 16933  16934  2015      2    4    13   13.0   NaN  Dingling
# 17007  17008  2015      2    7    15    3.0   NaN  Dingling
# 17030  17031  2015      2    8    14    4.0   NaN  Dingling
# 17052  17053  2015      2    9    12   87.0   NaN  Dingling
# 17053  17054  2015      2    9    13   95.0   NaN  Dingling
# 17078  17079  2015      2   10    14   29.0   NaN  Dingling
# 17090  17091  2015      2   11     2   12.0   NaN  Dingling
# 17112  17113  2015      2   12     0    7.0   NaN  Dingling
# 17150  17151  2015      2   13    14  113.0   NaN  Dingling
# ...

# %%
# mengisi data yang hilang dengan median
dingling_df['TEMP'].fillna(dingling_df['TEMP'].median(), inplace=True)

# %%
# melihat outlier
dingling_df['TEMP'].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# ### Membersihkan data stasiun Dongshi

# %%
# menghapus kolom yang tidak digunakan
dongsi_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
dongsi_df[dongsi_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP station
# 616      617  2013      3   26    16    NaN  13.5  Dongsi
# 1092    1093  2013      4   15    12    NaN  17.9  Dongsi
# 1642    1643  2013      5    8    10    NaN  22.1  Dongsi
# 1643    1644  2013      5    8    11    NaN  22.7  Dongsi
# 2304    2305  2013      6    5     0    NaN  18.5  Dongsi
# ...      ...   ...    ...  ...   ...    ...   ...     ...
# 34913  34914  2017      2   22    17    NaN   6.8  Dongsi
# 35030  35031  2017      2   27    14    NaN  14.2  Dongsi
# 35031  35032  2017      2   27    15    NaN  15.7  Dongsi
# 35032  35033  2017      2   27    16    NaN  15.9  Dongsi
# 35033  35034  2017      2   27    17    NaN  15.4  Dongsi
#
# [750 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
dongsi_df['PM2.5'].fillna(dongsi_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
dongsi_df['PM2.5'].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %%
dongsi_df['PM2.5'][dongsi_df['PM2.5'] > 600].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %%
# melihat missing value pada atribut TEMP
dongsi_df[dongsi_df['TEMP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP station
# 16748  16749  2015      1   27    20   35.0   NaN  Dongsi
# 17263  17264  2015      2   18     7   12.0   NaN  Dongsi
# 31047  31048  2016      9   14    15   78.0   NaN  Dongsi
# 31315  31316  2016      9   25    19  183.0   NaN  Dongsi
# 31316  31317  2016      9   25    20  143.0   NaN  Dongsi
# 31317  31318  2016      9   25    21  106.0   NaN  Dongsi
# 31318  31319  2016      9   25    22   95.0   NaN  Dongsi
# 31319  31320  2016      9   25    23   90.0   NaN  Dongsi
# 31320  31321  2016      9   26     0   88.0   NaN  Dongsi
# 33872  33873  2017      1   10     8    7.0   NaN  Dongsi
# 33882  33883  2017      1   10    18   15.0   NaN  Dongsi
# 34083  34084  2017      1   19     3  102.0   NaN  Dongsi
# 34084  34085  2017      1   19     4  118.0   NaN  Dongsi
# 34085  34086  2017      1   19     5  135.0   NaN  Dongsi
# 34086  34087  2017      1   19     6  117.0   NaN  Dongsi
# ...

# %%
# mengisi data yang hilang dengan median
dongsi_df['TEMP'].fillna(dongsi_df['TEMP'].median(), inplace=True)

# %%
# melihat outlier
dongsi_df['TEMP'].hist(bins=15) #tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# ### Mebersihkan data stasiun Guanyuan

# %%
# menghapus kolom yang tidak digunakan
guanyuan_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
guanyuan_df[guanyuan_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP   station
# 874      875  2013      4    6    10    NaN  10.8  Guanyuan
# 875      876  2013      4    6    11    NaN  11.3  Guanyuan
# 1089    1090  2013      4   15     9    NaN  14.2  Guanyuan
# 1721    1722  2013      5   11    17    NaN  31.9  Guanyuan
# 1722    1723  2013      5   11    18    NaN  30.1  Guanyuan
# ...      ...   ...    ...  ...   ...    ...   ...       ...
# 35043  35044  2017      2   28     3    NaN   7.3  Guanyuan
# 35044  35045  2017      2   28     4    NaN   7.0  Guanyuan
# 35045  35046  2017      2   28     5    NaN   5.3  Guanyuan
# 35046  35047  2017      2   28     6    NaN   9.5  Guanyuan
# 35047  35048  2017      2   28     7    NaN   8.4  Guanyuan
#
# [616 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
guanyuan_df['PM2.5'].fillna(guanyuan_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
guanyuan_df['PM2.5'].hist(bins=15) #tidak memiliki outlier
# Out:
# <Axes: >

# %%
# menangani missing value pada kolom TEMP
guanyuan_df[guanyuan_df["TEMP"].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP   station
# 16748  16749  2015      1   27    20   30.0   NaN  Guanyuan
# 17263  17264  2015      2   18     7   10.0   NaN  Guanyuan
# 31047  31048  2016      9   14    15   70.0   NaN  Guanyuan
# 31315  31316  2016      9   25    19  180.0   NaN  Guanyuan
# 31316  31317  2016      9   25    20  186.0   NaN  Guanyuan
# 31317  31318  2016      9   25    21  117.0   NaN  Guanyuan
# 31318  31319  2016      9   25    22  102.0   NaN  Guanyuan
# 31319  31320  2016      9   25    23   97.0   NaN  Guanyuan
# 31320  31321  2016      9   26     0   92.0   NaN  Guanyuan
# 33872  33873  2017      1   10     8    8.0   NaN  Guanyuan
# 33882  33883  2017      1   10    18   43.0   NaN  Guanyuan
# 34083  34084  2017      1   19     3   98.0   NaN  Guanyuan
# 34084  34085  2017      1   19     4   97.0   NaN  Guanyuan
# 34085  34086  2017      1   19     5  108.0   NaN  Guanyuan
# 34086  34087  2017      1   19     6  114.0   NaN  Guanyuan
# ...

# %%
# mengisi data yang hilang dengan median
guanyuan_df['TEMP'].fillna(guanyuan_df['TEMP'].median(), inplace=True)

# %%
# melihat outlier
guanyuan_df['TEMP'].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# ### Membersihkan data stasiun Gucheng

# %%
# menghapus kolom yang tidak digunakan
gucheng_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
gucheng_df[gucheng_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP  station
# 995      996  2013      4   11    11    NaN  13.8  Gucheng
# 996      997  2013      4   11    12    NaN  14.9  Gucheng
# 997      998  2013      4   11    13    NaN  16.4  Gucheng
# 998      999  2013      4   11    14    NaN  17.0  Gucheng
# 999     1000  2013      4   11    15    NaN  17.1  Gucheng
# ...      ...   ...    ...  ...   ...    ...   ...      ...
# 34910  34911  2017      2   22    14    NaN   2.8  Gucheng
# 34911  34912  2017      2   22    15    NaN   4.0  Gucheng
# 34912  34913  2017      2   22    16    NaN   5.1  Gucheng
# 34913  34914  2017      2   22    17    NaN   6.1  Gucheng
# 34914  34915  2017      2   22    18    NaN   5.6  Gucheng
#
# [646 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
gucheng_df['PM2.5'].fillna(gucheng_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
gucheng_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
gucheng_df['PM2.5'][gucheng_df['PM2.5']> 600].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %%
# melihat missing value pada atribut TEMP
gucheng_df[gucheng_df['TEMP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP  station
# 3960    3961  2013      8   13     0   94.0   NaN  Gucheng
# 3961    3962  2013      8   13     1   98.0   NaN  Gucheng
# 3962    3963  2013      8   13     2   96.0   NaN  Gucheng
# 3963    3964  2013      8   13     3  106.0   NaN  Gucheng
# 3964    3965  2013      8   13     4   97.0   NaN  Gucheng
# 3965    3966  2013      8   13     5   85.0   NaN  Gucheng
# 3966    3967  2013      8   13     6   91.0   NaN  Gucheng
# 14903  14904  2014     11   11    23    7.0   NaN  Gucheng
# 16766  16767  2015      1   28    14   28.0   NaN  Gucheng
# 16810  16811  2015      1   30    10   15.0   NaN  Gucheng
# 16813  16814  2015      1   30    13    5.0   NaN  Gucheng
# 16874  16875  2015      2    2     2  101.0   NaN  Gucheng
# 16878  16879  2015      2    2     6  111.0   NaN  Gucheng
# 16909  16910  2015      2    3    13  134.0   NaN  Gucheng
# 16930  16931  2015      2    4    10    8.0   NaN  Gucheng
# ...

# %%
# mengisi data yang hilang dengan median
gucheng_df['TEMP'].fillna(gucheng_df['TEMP'].median(), inplace=True)

# %% [markdown]
# ### Membersihkan data stasiun Huariou

# %%
# menghapus kolom yang tidak digunakan
huairou_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
huairou_df[huairou_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP  station
# 91        92  2013      3    4    19    NaN   5.6  Huairou
# 92        93  2013      3    4    20    NaN   3.5  Huairou
# 93        94  2013      3    4    21    NaN   2.3  Huairou
# 94        95  2013      3    4    22    NaN   2.1  Huairou
# 95        96  2013      3    4    23    NaN   1.4  Huairou
# ...      ...   ...    ...  ...   ...    ...   ...      ...
# 34879  34880  2017      2   21     7    NaN  -5.2  Huairou
# 34880  34881  2017      2   21     8    NaN  -3.6  Huairou
# 34883  34884  2017      2   21    11    NaN  -0.6  Huairou
# 34885  34886  2017      2   21    13    NaN   0.3  Huairou
# 34934  34935  2017      2   23    14    NaN   7.0  Huairou
#
# [953 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
huairou_df['PM2.5'].fillna(huairou_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
huairou_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
huairou_df['PM2.5'][huairou_df['PM2.5']> 400].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %%
# melihat missing value pada atribut TEMP
huairou_df[huairou_df['TEMP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP  station
# 15899  15900  2014     12   23    11   53.0   NaN  Huairou
# 15900  15901  2014     12   23    12   47.0   NaN  Huairou
# 16740  16741  2015      1   27    12   14.0   NaN  Huairou
# 16741  16742  2015      1   27    13   13.0   NaN  Huairou
# 16752  16753  2015      1   28     0   48.0   NaN  Huairou
# 16761  16762  2015      1   28     9   12.0   NaN  Huairou
# 16764  16765  2015      1   28    12   10.0   NaN  Huairou
# 16765  16766  2015      1   28    13   10.0   NaN  Huairou
# 16766  16767  2015      1   28    14   12.0   NaN  Huairou
# 16810  16811  2015      1   30    10   22.0   NaN  Huairou
# 16811  16812  2015      1   30    11   16.0   NaN  Huairou
# 16814  16815  2015      1   30    14   11.0   NaN  Huairou
# 16837  16838  2015      1   31    13   13.0   NaN  Huairou
# 16874  16875  2015      2    2     2   59.0   NaN  Huairou
# 16909  16910  2015      2    3    13  178.0   NaN  Huairou
# ...

# %%
# mengisi data yang hilang dengan median
huairou_df['TEMP'].fillna(huairou_df['TEMP'].median(), inplace=True)

# %%
# melihat outlier
huairou_df['TEMP'].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# ### Membersihkan data stasiun Nongzhanguan

# %%
# menghapus kolom yang tidak digunakan
nongzhanguan_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
nongzhanguan_df[nongzhanguan_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP       station
# 1258    1259  2013      4   22    10    NaN  14.1  Nongzhanguan
# 1259    1260  2013      4   22    11    NaN  14.5  Nongzhanguan
# 1260    1261  2013      4   22    12    NaN  14.3  Nongzhanguan
# 1331    1332  2013      4   25    11    NaN  20.0  Nongzhanguan
# 1620    1621  2013      5    7    12    NaN  28.8  Nongzhanguan
# ...      ...   ...    ...  ...   ...    ...   ...           ...
# 35026  35027  2017      2   27    10    NaN   6.8  Nongzhanguan
# 35029  35030  2017      2   27    13    NaN  14.0  Nongzhanguan
# 35042  35043  2017      2   28     2    NaN   8.6  Nongzhanguan
# 35054  35055  2017      2   28    14    NaN  14.6  Nongzhanguan
# 35055  35056  2017      2   28    15    NaN  15.4  Nongzhanguan
#
# [628 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
nongzhanguan_df['PM2.5'].fillna(nongzhanguan_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
nongzhanguan_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
nongzhanguan_df['PM2.5'][nongzhanguan_df['PM2.5'] > 400].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %%
# melihat missing value pada atribut TEMP
nongzhanguan_df[nongzhanguan_df['TEMP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP       station
# 16748  16749  2015      1   27    20   36.0   NaN  Nongzhanguan
# 17263  17264  2015      2   18     7   12.0   NaN  Nongzhanguan
# 31047  31048  2016      9   14    15   74.0   NaN  Nongzhanguan
# 31315  31316  2016      9   25    19  168.0   NaN  Nongzhanguan
# 31316  31317  2016      9   25    20  137.0   NaN  Nongzhanguan
# 31317  31318  2016      9   25    21  112.0   NaN  Nongzhanguan
# 31318  31319  2016      9   25    22   94.0   NaN  Nongzhanguan
# 31319  31320  2016      9   25    23   85.0   NaN  Nongzhanguan
# 31320  31321  2016      9   26     0   80.0   NaN  Nongzhanguan
# 33872  33873  2017      1   10     8    5.0   NaN  Nongzhanguan
# 33882  33883  2017      1   10    18    8.0   NaN  Nongzhanguan
# 34083  34084  2017      1   19     3  102.0   NaN  Nongzhanguan
# 34084  34085  2017      1   19     4  141.0   NaN  Nongzhanguan
# 34085  34086  2017      1   19     5  118.0   NaN  Nongzhanguan
# ...

# %%
# mengisi data yang hilang dengan median
nongzhanguan_df['TEMP'].fillna(nongzhanguan_df['TEMP'].median(), inplace=True)

# %%
# melihat outlier
nongzhanguan_df['TEMP'].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# #### Membersihkan data stasiun Shunyi

# %%
# menghapus kolom yang tidak digunakan
shunyi_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
shunyi_df[shunyi_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP station
# 204      205  2013      3    9    12    NaN  12.7  Shunyi
# 205      206  2013      3    9    13    NaN  10.4  Shunyi
# 206      207  2013      3    9    14    NaN   9.8  Shunyi
# 207      208  2013      3    9    15    NaN   9.7  Shunyi
# 208      209  2013      3    9    16    NaN  10.3  Shunyi
# ...      ...   ...    ...  ...   ...    ...   ...     ...
# 34880  34881  2017      2   21     8    NaN  -2.1  Shunyi
# 34883  34884  2017      2   21    11    NaN  -0.2  Shunyi
# 34885  34886  2017      2   21    13    NaN  -0.1  Shunyi
# 34936  34937  2017      2   23    16    NaN   8.1  Shunyi
# 34937  34938  2017      2   23    17    NaN   7.5  Shunyi
#
# [913 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
shunyi_df['PM2.5'].fillna(shunyi_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
shunyi_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
huairou_df['PM2.5'][huairou_df['PM2.5'] > 400].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %%
# melihat missing value pada atribut TEMP
shunyi_df[shunyi_df['TEMP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP station
# 16760  16761  2015      1   28     8    7.0   NaN  Shunyi
# 16790  16791  2015      1   29    14   32.0   NaN  Shunyi
# 16812  16813  2015      1   30    12   15.0   NaN  Shunyi
# 16813  16814  2015      1   30    13   12.0   NaN  Shunyi
# 16873  16874  2015      2    2     1  271.0   NaN  Shunyi
# 16907  16908  2015      2    3    11  225.0   NaN  Shunyi
# 16930  16931  2015      2    4    10   22.0   NaN  Shunyi
# 16932  16933  2015      2    4    12   16.0   NaN  Shunyi
# 16934  16935  2015      2    4    14   19.0   NaN  Shunyi
# 16982  16983  2015      2    6    14   27.0   NaN  Shunyi
# 17007  17008  2015      2    7    15    8.0   NaN  Shunyi
# 17053  17054  2015      2    9    13   87.0   NaN  Shunyi
# 17078  17079  2015      2   10    14   61.0   NaN  Shunyi
# 17115  17116  2015      2   12     3   13.0   NaN  Shunyi
# 17125  17126  2015      2   12    13   18.0   NaN  Shunyi
# ...

# %%
# mengisi data yang hilang dengan median
shunyi_df['TEMP'].fillna(shunyi_df['TEMP'].median(), inplace=True)

# %%
# melihat outlier
shunyi_df['TEMP'].hist(bins=15) #tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# ### Membersihkan data stasiun Tiantan

# %%
# menghapus kolom yang tidak digunakan
tiantan_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
tiantan_df[tiantan_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP  station
# 174      175  2013      3    8     6    NaN   3.5  Tiantan
# 175      176  2013      3    8     7    NaN   6.6  Tiantan
# 178      179  2013      3    8    10    NaN  19.9  Tiantan
# 1282    1283  2013      4   23    10    NaN  12.6  Tiantan
# 1283    1284  2013      4   23    11    NaN  13.8  Tiantan
# ...      ...   ...    ...  ...   ...    ...   ...      ...
# 34885  34886  2017      2   21    13    NaN  -2.1  Tiantan
# 35017  35018  2017      2   27     1    NaN   5.0  Tiantan
# 35030  35031  2017      2   27    14    NaN  14.2  Tiantan
# 35031  35032  2017      2   27    15    NaN  15.7  Tiantan
# 35032  35033  2017      2   27    16    NaN  15.9  Tiantan
#
# [677 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
tiantan_df['PM2.5'].fillna(tiantan_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
tiantan_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
tiantan_df[tiantan_df['PM2.5'] > 600] #tidak memiliki outlier
# Out:
#           No  year  month  day  hour  PM2.5   TEMP  station
# 24110  24111  2015     11   30    14  667.0  0.000  Tiantan
# 24111  24112  2015     11   30    15  671.0  0.400  Tiantan
# 24112  24113  2015     11   30    16  651.0  0.200  Tiantan
# 24113  24114  2015     11   30    17  650.0 -0.500  Tiantan
# 24114  24115  2015     11   30    18  604.0 -1.200  Tiantan
# 24127  24128  2015     12    1     7  606.0 -0.700  Tiantan
# 24128  24129  2015     12    1     8  610.0 -0.400  Tiantan
# 24131  24132  2015     12    1    11  626.0  0.400  Tiantan
# 24132  24133  2015     12    1    12  641.0  0.300  Tiantan
# 24133  24134  2015     12    1    13  601.0  0.200  Tiantan
# 24710  24711  2015     12   25    14  618.0 -2.000  Tiantan
# 24711  24712  2015     12   25    15  631.0 -1.400  Tiantan
# 25779  25780  2016      2    8     3  821.0 -2.600  Tiantan
# 25780  25781  2016      2    8     4  801.0 -2.500  Tiantan
# 25781  25782  2016      2    8     5  758.0 -3.000  Tiantan
# ...

# %%
# melihat outlier
tiantan_df['TEMP'].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# ### Membersihkan data stasiun Wanliu

# %%
# menghapus kolom yang tidak digunakan
wanliu_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
wanliu_df[wanliu_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP station
# 1263    1264  2013      4   22    15    NaN  14.7  Wanliu
# 1383    1384  2013      4   27    15    NaN  23.9  Wanliu
# 1384    1385  2013      4   27    16    NaN  23.0  Wanliu
# 1385    1386  2013      4   27    17    NaN  21.8  Wanliu
# 1648    1649  2013      5    8    16    NaN  21.6  Wanliu
# ...      ...   ...    ...  ...   ...    ...   ...     ...
# 34879  34880  2017      2   21     7    NaN  -1.8  Wanliu
# 34880  34881  2017      2   21     8    NaN  -0.9  Wanliu
# 34883  34884  2017      2   21    11    NaN   0.5  Wanliu
# 34885  34886  2017      2   21    13    NaN  -2.0  Wanliu
# 34907  34908  2017      2   22    11    NaN  -0.1  Wanliu
#
# [382 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
wanliu_df['PM2.5'].fillna(wanliu_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
wanliu_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
wanliu_df['PM2.5'][wanliu_df['PM2.5']>600].hist(bins=15)
# Out:
# <Axes: >

# %%
wanliu_df['PM2.5'].replace(wanliu_df['PM2.5'].max(), wanliu_df['PM2.5'].median(), inplace=True)

# %%
huairou_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
# mengisi data yang hilang dengan median
wanliu_df['TEMP'].fillna(wanliu_df['TEMP'].median(), inplace=True)

# %%
# melihat outlier
wanliu_df['TEMP'].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# ### Membersihkan data stasiun Wanshouxigong

# %%
# menghapus kolom yang tidak digunakan
wanshouxigong_df.drop(columns=['PM10', 'SO2', 'NO2', 'CO', 'O3', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'], inplace=True)

# %%
# melihat missing value pada atribut PM2.5
wanshouxigong_df[wanshouxigong_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP        station
# 1095    1096  2013      4   15    15    NaN  18.6  Wanshouxigong
# 1142    1143  2013      4   17    14    NaN  17.1  Wanshouxigong
# 1816    1817  2013      5   15    16    NaN  26.8  Wanshouxigong
# 2293    2294  2013      6    4    13    NaN  22.8  Wanshouxigong
# 2294    2295  2013      6    4    14    NaN  20.7  Wanshouxigong
# ...      ...   ...    ...  ...   ...    ...   ...            ...
# 34992  34993  2017      2   26     0    NaN   4.2  Wanshouxigong
# 35005  35006  2017      2   26    13    NaN  12.4  Wanshouxigong
# 35027  35028  2017      2   27    11    NaN  10.0  Wanshouxigong
# 35028  35029  2017      2   27    12    NaN  12.1  Wanshouxigong
# 35029  35030  2017      2   27    13    NaN  14.0  Wanshouxigong
#
# [696 rows x 8 columns]

# %%
# mengisi data yang hilang dengan median
wanshouxigong_df['PM2.5'].fillna(wanshouxigong_df['PM2.5'].median(), inplace=True)

# %%
# melihat outlier
wanshouxigong_df['PM2.5'].hist(bins=15)
# Out:
# <Axes: >

# %%
wanshouxigong_df[wanshouxigong_df['PM2.5'] > 700]
# Out:
#           No  year  month  day  hour  PM2.5   TEMP        station
# 8423    8424  2014      2   14    23  704.0 -4.300  Wanshouxigong
# 25777  25778  2016      2    8     1  826.0 -1.700  Wanshouxigong
# 25778  25779  2016      2    8     2  999.0 -1.600  Wanshouxigong
# 25779  25780  2016      2    8     3  857.0 -2.600  Wanshouxigong
# 25780  25781  2016      2    8     4  748.0 -2.500  Wanshouxigong
# 34297  34298  2017      1   28     1  804.0 -0.525  Wanshouxigong
# 34298  34299  2017      1   28     2  730.0 -2.975  Wanshouxigong
# 34299  34300  2017      1   28     3  823.0 -4.000  Wanshouxigong

# %%
wanshouxigong_df['PM2.5'].replace(wanshouxigong_df['PM2.5'].max(), wanshouxigong_df['PM2.5'].median(), inplace=True)

# %%
# melihat missing value pada atribut TEMP
wanshouxigong_df[wanshouxigong_df['TEMP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5  TEMP        station
# 17263  17264  2015      2   18     7   16.0   NaN  Wanshouxigong
# 31047  31048  2016      9   14    15   74.0   NaN  Wanshouxigong
# 31315  31316  2016      9   25    19  174.0   NaN  Wanshouxigong
# 31316  31317  2016      9   25    20  162.0   NaN  Wanshouxigong
# 31317  31318  2016      9   25    21  100.0   NaN  Wanshouxigong
# 31318  31319  2016      9   25    22   89.0   NaN  Wanshouxigong
# 31319  31320  2016      9   25    23   87.0   NaN  Wanshouxigong
# 31320  31321  2016      9   26     0   85.0   NaN  Wanshouxigong
# 33872  33873  2017      1   10     8    7.0   NaN  Wanshouxigong
# 33882  33883  2017      1   10    18   65.0   NaN  Wanshouxigong
# 34083  34084  2017      1   19     3  109.0   NaN  Wanshouxigong
# 34084  34085  2017      1   19     4  102.0   NaN  Wanshouxigong
# 34085  34086  2017      1   19     5  111.0   NaN  Wanshouxigong
# ...

# %%
# mengisi data yang hilang dengan median
wanshouxigong_df['TEMP'].fillna(wanshouxigong_df['TEMP'].median(), inplace=True)

# %%
# melihat outlier
wanshouxigong_df['TEMP'].hist(bins=15) # tidak memiliki outlier
# Out:
# <Axes: >

# %% [markdown]
# ### menggabungkan seluruh dataset

# %%
All_df = pd.concat([
    aotizongxin_df,
    changping_df,
    dingling_df,
    shunyi_df,
    wanliu_df,
    dongsi_df,
    gucheng_df,
    huairou_df,
    tiantan_df,
    guanyuan_df,
    nongzhanguan_df,
    wanshouxigong_df],
    ignore_index=True
)
All_df['date'] = pd.to_datetime(All_df[['year', 'month', 'day']])
bins = [0, 12.1, 35.5, 55.5, 150.5, 250.5, float('inf')]
labels = ['Baik', 'Sedang', 'Tidak Sehat bagi kelompok sensitif','Tidak sehat','Sangat tidak sehat', 'Berbahaya']

All_df['Category_PM2.5'] = pd.cut(All_df['PM2.5'], bins=bins, labels=labels, right=False)
result = All_df.groupby(['station','Category_PM2.5' ]).size().unstack(fill_value=0)
print(result)
# Out:
# Category_PM2.5  Baik  Sedang  Tidak Sehat bagi kelompok sensitif  Tidak sehat  \
# station
# Aotizhongxin    4604    7537                                4379        13019
# Changping       5480    9050                                5216        10946
# Dingling        7796    8169                                5151         9965
# Dongsi          4958    6962                                4226        12978
# Guanyuan        4242    7685                                4574        13132
# Gucheng         4635    7031                                4686        13252
# Huairou         6025    8479                                5412        11058
# Nongzhanguan    4986    7219                                4380        12677
# Shunyi          5615    7310                                5189        11723
# Tiantan         4831    7255                                4491        13026
# Wanliu          4651    7393                                4641        12724
# ...

# %%
monthly_avg_temp = All_df.groupby(['station','year','month'])['TEMP'].mean().reset_index()
print (monthly_avg_temp)
# Out:
#            station  year  month       TEMP
# 0     Aotizhongxin  2013      3   6.053629
# 1     Aotizhongxin  2013      4  12.260694
# 2     Aotizhongxin  2013      5  21.374194
# 3     Aotizhongxin  2013      6  23.386111
# 4     Aotizhongxin  2013      7  26.877419
# ..             ...   ...    ...        ...
# 571  Wanshouxigong  2016     10  13.338648
# 572  Wanshouxigong  2016     11   4.414028
# 573  Wanshouxigong  2016     12   0.640726
# 574  Wanshouxigong  2017      1  -0.912254
# 575  Wanshouxigong  2017      2   2.661533
#
# [576 rows x 4 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Eksplor

# %% [markdown]
# #### eksplor data PM2.5 di setiap stasiun

# %%
# eksplor kadar PM2.5 di stasiun Aotizongxin
All_df.describe(include= "all")
# Out:
#                    No           year          month            day  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     17532.500000    2014.662560       6.522930      15.729637
# min          1.000000    2013.000000       1.000000       1.000000
# 25%       8766.750000    2014.000000       4.000000       8.000000
# 50%      17532.500000    2015.000000       7.000000      16.000000
# 75%      26298.250000    2016.000000      10.000000      23.000000
# max      35064.000000    2017.000000      12.000000      31.000000
# std      10122.116943       1.177198       3.448707       8.800102
#
#                  hour          PM2.5           TEMP       station  \
# count   420768.000000  420768.000000  420748.000000        420768
# ...

# %% [markdown]
# berdasarkan data diatas menunjukkan bahwa rata-rata kadar PM2.5 di udara adalah 79 dan suhu rata-rata adalah 13.5 derajat celcius

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di aotizongxin
aotizongxin_df['Category_PM2.5'] = pd.cut(aotizongxin_df['PM2.5'], bins=bins, labels=labels, right=False)
aotizongxin_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-153-8b75d79b52b2>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   aotizongxin_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           13019
# Sedang                                 7537
# Baik                                   4604
# Tidak Sehat bagi kelompok sensitif     4379
# Sangat tidak sehat                     3876
# Berbahaya                              1649
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di changping
changping_df['Category_PM2.5'] = pd.cut(changping_df['PM2.5'], bins=bins, labels=labels, right=False)
changping_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-154-a6734df58698>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   changping_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           10946
# Sedang                                 9050
# Baik                                   5480
# Tidak Sehat bagi kelompok sensitif     5216
# Sangat tidak sehat                     3279
# Berbahaya                              1093
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di dingling
dingling_df['Category_PM2.5'] = pd.cut(dingling_df['PM2.5'], bins=bins, labels=labels, right=False)
dingling_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-155-41f9130f9a4e>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dingling_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           9965
# Sedang                                8169
# Baik                                  7796
# Tidak Sehat bagi kelompok sensitif    5151
# Sangat tidak sehat                    2880
# Berbahaya                             1103
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di dongsi
dongsi_df['Category_PM2.5'] = pd.cut(dongsi_df['PM2.5'], bins=bins, labels=labels, right=False)
dongsi_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-156-b7055bd5a7d0>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dongsi_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           12978
# Sedang                                 6962
# Baik                                   4958
# Tidak Sehat bagi kelompok sensitif     4226
# Sangat tidak sehat                     4016
# Berbahaya                              1924
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di guanyuan
guanyuan_df['Category_PM2.5'] = pd.cut(guanyuan_df['PM2.5'], bins=bins, labels=labels, right=False)
guanyuan_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-157-4dd1cd7a8f66>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   guanyuan_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           13132
# Sedang                                 7685
# Tidak Sehat bagi kelompok sensitif     4574
# Baik                                   4242
# Sangat tidak sehat                     3871
# Berbahaya                              1560
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di gucheng
gucheng_df['Category_PM2.5'] = pd.cut(gucheng_df['PM2.5'], bins=bins, labels=labels, right=False)
gucheng_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-158-b9cd28c67bee>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gucheng_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           13252
# Sedang                                 7031
# Tidak Sehat bagi kelompok sensitif     4686
# Baik                                   4635
# Sangat tidak sehat                     3819
# Berbahaya                              1641
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di huairou
huairou_df['Category_PM2.5'] = pd.cut(huairou_df['PM2.5'], bins=bins, labels=labels, right=False)
huairou_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-159-4307ca1a738d>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   huairou_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           11058
# Sedang                                 8479
# Baik                                   6025
# Tidak Sehat bagi kelompok sensitif     5412
# Sangat tidak sehat                     3118
# Berbahaya                               972
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di nongzhanguan
nongzhanguan_df['Category_PM2.5'] = pd.cut(nongzhanguan_df['PM2.5'], bins=bins, labels=labels, right=False)
nongzhanguan_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-160-9832e9cf6700>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   nongzhanguan_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           12677
# Sedang                                 7219
# Baik                                   4986
# Tidak Sehat bagi kelompok sensitif     4380
# Sangat tidak sehat                     3900
# Berbahaya                              1902
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di shunyi
shunyi_df['Category_PM2.5'] = pd.cut(shunyi_df['PM2.5'], bins=bins, labels=labels, right=False)
shunyi_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-161-08e5ad1ab3cc>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   shunyi_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           11723
# Sedang                                 7310
# Baik                                   5615
# Tidak Sehat bagi kelompok sensitif     5189
# Sangat tidak sehat                     3697
# Berbahaya                              1530
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di tiantan
tiantan_df['Category_PM2.5'] = pd.cut(tiantan_df['PM2.5'], bins=bins, labels=labels, right=False)
tiantan_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-162-bfa41eb22398>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tiantan_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           13026
# Sedang                                 7255
# Baik                                   4831
# Tidak Sehat bagi kelompok sensitif     4491
# Sangat tidak sehat                     3884
# Berbahaya                              1577
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di wanliu
wanliu_df['Category_PM2.5'] = pd.cut(wanliu_df['PM2.5'], bins=bins, labels=labels, right=False)
wanliu_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-163-2ecaa9d4e8cb>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   wanliu_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           12724
# Sedang                                 7393
# Baik                                   4651
# Tidak Sehat bagi kelompok sensitif     4641
# Sangat tidak sehat                     4001
# Berbahaya                              1654
# Name: No, dtype: int64

# %%
# melihat kualitas udara berdasrkan polutan PM2.5 di wanshouxigong
wanshouxigong_df['Category_PM2.5'] = pd.cut(wanshouxigong_df['PM2.5'], bins=bins, labels=labels, right=False)
wanshouxigong_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Out:
# <ipython-input-164-f09216d32c28>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   wanshouxigong_df.groupby(by='Category_PM2.5').No.nunique().sort_values(ascending=False)
# Category_PM2.5
# Tidak sehat                           13063
# Sedang                                 7006
# Baik                                   4952
# Tidak Sehat bagi kelompok sensitif     4325
# Sangat tidak sehat                     3893
# Berbahaya                              1825
# Name: No, dtype: int64

# %% [markdown]
# ### Visualization

# %% [markdown]
# #### Bagaimanakah kualitas udara berdasarkan polutan PM2.5 di setiap kota

# %%
sns.set(style='white')

# Plotting stacked bar chart
ax = result.plot(kind='bar', stacked=True, color=['green', 'yellow' ,'orange', 'red','grey','black'])

# Menambahkan judul dan label sumbu
plt.title('Air Quality PM2.5 Pollutant Based', fontsize=15)
plt.xlabel('Station', fontsize=10)
plt.ylabel('Category', fontsize=10)
plt.xticks(rotation=75, fontsize=8)
plt.yticks(fontsize=8)
ax.legend(title='Kategori', title_fontsize='7', fontsize='5', bbox_to_anchor=(1.05, 1), loc='upper left')
# Tampilkan grafik
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Bagaimanakah tren suhu taunan terjadi di seluruh kota setiap bulannya?

# %%
# Plot tren suhu bulanan 2013
monthly_avg_2013 = monthly_avg_temp[monthly_avg_temp['year'] == 2013]



for station in monthly_avg_2013['station'].unique():
    subset = monthly_avg_2013[monthly_avg_2013['station'] == station]
    plt.plot(subset['month'], subset['TEMP'], marker='o', label=station)

plt.title('Tren Suhu Bulanan Setiap Stasiun (2013)', fontsize=25)
plt.xlabel('Bulan')
plt.ylabel('Suhu Rata-rata')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Agu', 'Sep', 'Okt', 'Nov', 'Des'])
plt.legend(title='Stasiun',title_fontsize='10', fontsize='8', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot tren suhu bulanan 2013

monthly_avg_2014 = monthly_avg_temp[monthly_avg_temp['year'] == 2014]

for station in monthly_avg_2014['station'].unique():
    subset = monthly_avg_2014[monthly_avg_2014['station'] == station]
    plt.plot(subset['month'], subset['TEMP'], marker='o', label=station)

plt.title('Tren Suhu Bulanan Setiap Stasiun (2014)', fontsize=25)
plt.xlabel('Bulan')
plt.ylabel('Suhu Rata-rata')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Agu', 'Sep', 'Okt', 'Nov', 'Des'])
plt.legend(title='Stasiun',title_fontsize='10', fontsize='8', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()


# Plot tren suhu bulanan 2015

monthly_avg_2015 = monthly_avg_temp[monthly_avg_temp['year'] == 2015]

for station in monthly_avg_2015['station'].unique():
    subset = monthly_avg_2015[monthly_avg_2015['station'] == station]
    plt.plot(subset['month'], subset['TEMP'], marker='o', label=station)

plt.title('Tren Suhu Bulanan Setiap Stasiun (2015)', fontsize=25)
plt.xlabel('Bulan')
plt.ylabel('Suhu Rata-rata')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Agu', 'Sep', 'Okt', 'Nov', 'Des'])
plt.legend(title='Stasiun',title_fontsize='10', fontsize='8', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot tren suhu bulanan 2016

monthly_avg_2016 = monthly_avg_temp[monthly_avg_temp['year'] == 2016]

for station in monthly_avg_2016['station'].unique():
    subset = monthly_avg_2016[monthly_avg_2016['station'] == station]
    plt.plot(subset['month'], subset['TEMP'], marker='o', label=station)

plt.title('Tren Suhu Bulanan Setiap Stasiun (2016)', fontsize=25)
plt.xlabel('Bulan')
plt.ylabel('Suhu Rata-rata')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Agu', 'Sep', 'Okt', 'Nov', 'Des'])
plt.legend(title='Stasiun',title_fontsize='10', fontsize='8', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
All_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  TEMP       station       date  \
# 0   1  2013      3    1     0    4.0  -0.7  Aotizhongxin 2013-03-01
# 1   2  2013      3    1     1    8.0  -1.1  Aotizhongxin 2013-03-01
# 2   3  2013      3    1     2    7.0  -1.1  Aotizhongxin 2013-03-01
# 3   4  2013      3    1     3    6.0  -1.4  Aotizhongxin 2013-03-01
# 4   5  2013      3    1     4    3.0  -2.0  Aotizhongxin 2013-03-01
#
#   Category_PM2.5
# 0           Baik
# 1           Baik
# 2           Baik
# 3           Baik
# 4           Baik

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Pertanyaan 1 : Bagaimanakah tren suhu taunan terjadi di seluruh kota setiap bulannya?
# Conclution 1 : Berdasarkan Analisis data yang telah dilakukan dapat disimpulkan bahwa kualitas udara yang ada di setiap kota berdasarkan polutan PM2.5 memiliki kualitas yang bervariasi, namun didominasi oleh kualitas udara tidak sehat di seluruh kota.

# %% [markdown]
# Pertanyaan 2 : Bagaimanakah tren suhu taunan terjadi di seluruh kota setiap bulannya?
# Conclution 2 : Berdasarkan analisis data yang telah dilakukan, dapat disimpulkan bahwa terdapat tren pola suhu tahunan yang sama di semua kota. Musim dingin berlangsung pada bulan november hingga pertengahan februari. Suhu hangat terjadi di pertengahan tahun di semua stasiun.
